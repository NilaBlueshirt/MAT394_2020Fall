# %% [markdown]
# # Exam 1 (10 points):
#
# ## Please put your name into the filename you submit.
# #### For example, my exam file will be 'WenweiZheng-Exam1.ipynb'
#
# ### Note
# We have 10 questions below.  You are free to use previous notes.  However google or discussing with the other people is not allowed.

# %% [markdown]
# ## Q1 (1 point)
# #### Please change the lines to bold, italic or both bold and italic according to the information in the line:

# %% [markdown]
# #### Your answer here:
#
# 1. **This is bold.**
#
# 2. *This is italic.*
#
# 3. ***This is bold and italic.***

# %% [markdown]
# ## Q2 (1 point)
# #### Can you help test word listed below which word is NOT a python keyword?
#
#     true
#     True
#     for
#     in

# %%
## Please give the keyword in the Markdown block below
true
True
for
in
# I can see that only the word "true" is not color coded.

# %% [markdown]
# ### Q2 answer: which one is not the keyword in that list?
#
# true

# %% [markdown]
# ## Q3 (1 point)
# #### What is the length of the vector `a` in the code below?  You are free to try in the code block below.

# %%
import numpy as np
a=np.matmul(np.arange(10),np.zeros([10,5]))

## Please give your answer to the Markdown block below
a.shape
# Out:
# (5,)

# %% [markdown]
# #### Q3 The length of the vector `a` is ?
#
# 5

# %% [markdown]
# ## Q4 (1 point)
#
# #### Can you generate a vector containing numbers of (0,1,2,3,4,5,6) and print out the MEAN of the vector using NumPy functions?

# %%
## Please put the code of Q4 here

import numpy as np

q4_vector = np.array([0, 1, 2, 3, 4, 5, 6])

print(np.mean(q4_vector))
# Out:
# 3.0

# %% [markdown]
# ## Q5 (1 point)
#
# #### Please calculate the equation below and print out the answer
# $$ \frac{4.25+3.2}{2.53} \times 5.2   $$

# %%
## Please put the code of Q5 here

print(  ((4.25 + 3.2) / 2.53) * 5.2  )
# Out:
# 15.312252964426879

# %% [markdown]
# ## Q6 (1 point)
# #### Please caculate the equation below and print out the answer
# $$\sum_{i=0}^{100} (\frac{i}{i+1})$$

# %%
## Please put the code of Q6 here
import numpy as np
i = np.arange(0,101)
print(sum( i/(i+1) ) )
# Out:
# 95.80272149226131

# %% [markdown]
# ## Q7 (1 point)
# #### Please replace the string 'HUNTER' as a title case version ('Hunter') and print out the new list

# %%
name_list= ['James','Robert','Alexandru','Alia','HUNTER','Jacob','Jonathan','Kenneth','Caleb','Merine','Angelina']

## Please put the code of Q7 here
name_list.remove('HUNTER')              # name_list[4] = 'Hunter'
name_list.insert(4, 'Hunter')
print(name_list)
# Out:
# ['James', 'Robert', 'Alexandru', 'Alia', 'Hunter', 'Jacob', 'Jonathan', 'Kenneth', 'Caleb', 'Merine', 'Angelina']

# %% [markdown]
# ## Q8 (1 point)
#
# #### For each name in the list, merge the first 3 characters and the last character of the name, and then print that out
#
# For example, 'James' will give 'Jams' and 'Robert' will give 'Robt'

# %%
import numpy as np
name_list= ['James','Robert','Alexandru','Alia','Hunter','Jacob','Jonathan','Kenneth','Caleb','Merine','Angelina']

for i in name_list:
    # the first three characters
    first3= i[:3]
    # the last character of the string
    last1= i[-1]
    # print out the merged version
    out = [first3, last1]
    
out_list = []
out_list = out_list.append(out)
print(out_list)
    #print([''.joint(i)for i, j in out ])
# Out:
# None

# %% [markdown]
# ## Q9 (1 point)
#
# #### For the dictionary provided in the coding block below, finish the following operations:
# #### 1. Change the value of 'Major' key to 'MAT'
# #### 2. Add one extra class 'Thesis' into the list of 'Course' key.
# #### 3. Add a new key 'Year' with a value of 'Junior' into the dictionary.

# %%
person={'Major':'ABS','Course':['MAT305','MAT315','ABS394']}
## Please put the code of Q9 here

person['Major'] = 'MAT'
person['Course'].append('Thesis')
person.setdefault('Year',[]).append(('Junior'))
print(person)
# Out:
# {'Major': 'MAT', 'Course': ['MAT305', 'MAT315', 'ABS394', 'Thesis'], 'Year': ['Junior']}

# %% [markdown]
# ## Q10 (1 point)
#
# #### Please print out all the integer numbers from 1 to 100 that has a remainder of 2 after being divided by 17.
# #### Note you can use `%` to get the remainder after division

# %%
## Please put the code of Q10 here
import nmupy as np
for i in np.arange(1, 101):
    if i%17==2:
        print(i)
# Out:
# 2
# 19
# 36
# 53
# 70
# 87

# %% [markdown]
# ## Extra credit (1 point)
#
# #### We would like to design a rectangular-shape swimming pool with the largest area within a budget of \$10000.
# #### The swimming pool builder usually calculate the price by using both the perimeter and area of the pool.
# #### If the two sides of the rectangular pool are `a` and `b` feet, and
# $$ price = 100(a+b) + 30ab$$
# #### can you find out the largest area for the pool ($area=ab$) within the budget?
# #### Note only interger is allowed for `a` and `b`.

# %%
## Please put the code of Extra credit here

## Here is a framework of enumerating possible pairs of a and b if you want to use directly
import numpy as np
import math

# result = []
for a in range(1,50):
    for b in range(1,50):
        area=a*b
        price=100*(a+b)+30*a*b
  
        price_vector = np.array(price)   #if price <=1000:
                                         #    result.append((area,price,a,b))
                                         #result.sort()
        print(np.fmax(price_vector))     # key = lambda x:X[0]
                                         #print(result[-1])
        print(where(price=?, a, b))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
maxarea = 0
for a in range(1,100):      # also can use numpy here, change range to  np. range 
                            # np.range(1, 100, step size default=1)
    for b in range(1,100):
        area =a*b
        price = 100*(a+b)+30*a*b
        if price <= 1000:
            if area > maxarea:
                maxarea = area
                res = (area, price, a, b)
print(res)
